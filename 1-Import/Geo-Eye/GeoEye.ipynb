# %%
import numpy as np
from skimage import io
import napari
import matplotlib.pyplot as plt

# %%
geo_eye = io.imread('E:/geoeye.tif')

# %%
geo_eye.shape
# Out:
# (800, 800, 4)

# %%
geo_eye.dtype
# Out:
# dtype('uint16')

# %%
geoE = np.array(geo_eye).astype(float)

# %%
geoE.dtype
# Out:
# dtype('float64')

# %%
Normalize = (geoE-np.min(geoE))/(np.max(geoE)-np.min(geoE))

# %%
Normalize.dtype
# Out:
# dtype('float64')

# %%
blue_1 = Normalize[:,:,0]

# %%
blue_1
# Out:
# array([[0.13049853, 0.13538612, 0.13685239, ..., 0.14467253, 0.14613881,
#         0.14516129],
#        [0.13245357, 0.13782991, 0.14613881, ..., 0.15102639, 0.14809384,
#         0.14369501],
#        [0.13098729, 0.13587488, 0.14565005, ..., 0.14907136, 0.15249267,
#         0.15200391],
#        ...,
#        [0.17106549, 0.16422287, 0.15982405, ..., 0.14125122, 0.14565005,
#         0.14320626],
#        [0.15640274, 0.15738025, 0.15298143, ..., 0.14320626, 0.14516129,
#         0.1427175 ],
#        [0.1627566 , 0.16911046, 0.15982405, ..., 0.14076246, 0.1402737 ,
#         0.14125122]])

# %%
plt.imshow(blue_1, cmap='gray')

# %%
blue_2 = Normalize[:,:,1]

# %%
blue_2
# Out:
# array([[0.16911046, 0.17350929, 0.17497556, ..., 0.17057674, 0.17155425,
#         0.17008798],
#        [0.17008798, 0.17497556, 0.1886608 , ..., 0.18230694, 0.17302053,
#         0.16568915],
#        [0.17253177, 0.17741935, 0.1945259 , ..., 0.17986315, 0.17888563,
#         0.18670577],
#        ...,
#        [0.23509286, 0.2228739 , 0.21407625, ..., 0.1769306 , 0.18084066,
#         0.17741935],
#        [0.20039101, 0.20625611, 0.20185728, ..., 0.17790811, 0.18523949,
#         0.18181818],
#        [0.22482893, 0.23362659, 0.21652004, ..., 0.17399804, 0.17497556,
#         0.17497556]])

# %%
plt.imshow(blue_2, cmap='gray')

# %%
blue_3 = Normalize[:,:,2]

# %%
blue_3
# Out:
# array([[0.08651026, 0.09286413, 0.09090909, ..., 0.10410557, 0.10997067,
#         0.1085044 ],
#        [0.08748778, 0.10215054, 0.11339198, ..., 0.1143695 , 0.11290323,
#         0.10312805],
#        [0.08797654, 0.10312805, 0.11925709, ..., 0.11241447, 0.10948192,
#         0.11779081],
#        ...,
#        [0.17106549, 0.15640274, 0.14467253, ..., 0.11681329, 0.1202346 ,
#         0.11241447],
#        [0.13489736, 0.13685239, 0.13538612, ..., 0.11779081, 0.12463343,
#         0.11827957],
#        [0.16129032, 0.16617791, 0.15102639, ..., 0.10948192, 0.10703812,
#         0.11290323]])

# %%
plt.imshow(blue_3, cmap='gray')

# %%
blue_4 = Normalize[:,:,3]

# %%
blue_4
# Out:
# array([[0.30351906, 0.30645161, 0.35483871, ..., 0.17302053, 0.16715543,
#         0.16080156],
#        [0.32355816, 0.28739003, 0.30694037, ..., 0.18230694, 0.17204301,
#         0.15542522],
#        [0.33186706, 0.29081134, 0.28690127, ..., 0.16959922, 0.16471163,
#         0.16129032],
#        ...,
#        [0.29618768, 0.27908113, 0.26441838, ..., 0.2228739 , 0.23362659,
#         0.22580645],
#        [0.242913  , 0.24389052, 0.2512219 , ..., 0.22580645, 0.2370479 ,
#         0.23167155],
#        [0.27370479, 0.28347996, 0.26637341, ..., 0.21896383, 0.23069404,
#         0.23216031]])

# %%
plt.imshow(blue_4, cmap='gray')
